# %%
pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from selenium import webdriver
driver = webdriver.Chrome()#Start the sessin
driver.implicitly_wait(0.8)
driver.get("https://www.google.com")#Take action on browser
driver.quit()

# %%
from selenium import webdriver
driver = webdriver.Chrome()#Start the sessin
driver.get("https://google.com")#Take action on browser
driver.implicitly_wait(0.3)
driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
driver = webdriver.Chrome()
driver.implicitly_wait(5)
driver.get("https://www.w3schools.com/python/default.asp")
titles = driver.find_elements(By.CLASS_NAME, "w3-example")
for t in titles:
    print(t.text)
driver.quit()
# Out:
# Example
# Get your own Python Server
# print("Hello, World!")
# Try it Yourself »

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
driver = webdriver.Chrome()
driver.implicitly_wait(5)
driver.get("https://www.w3schools.com/python/default.asp")
titles = driver.find_elements(By.ID, "exercisecontainer")
for t in titles:
    print(t.text)
driver.quit()
# Out:
# Exercise
# ?
#
# What is a correct way to declare a Python variable?
#
# var x = 5
# #x = 5
# $x = 5
# x = 5
#
# Submit Answer »

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
driver = webdriver.Chrome()
driver.implicitly_wait(5)
driver.get("https://www.geeksforgeeks.org/machine-learning/python-for-machine-learning/")
titles = driver.find_elements(By.CLASS_NAME, "root")
for t in titles:
    print(t.text)
driver.quit()
# Out:
# Python for Machine Learning
# Machine Learning with R
# Machine Learning Algorithms
# EDA
# Math for Machine Learning
# Machine Learning Interview Questions
# ML Projects
# Deep Learning
# NLP
# Computer vision
# Technical Scripter 2026
# Machine Learning Basics
# Python for Machine Learning
# Feature Engineering
# Supervised Learning
# Unsupervised Learning
# Model Evaluation and Tuning
# Advanced Techniques
# Machine Learning Practice
# ML & Data Science
# 90% Refund
# Python for Machine Learning
# Last Updated : 27 Nov, 2025
# Python is the backbone of today’s Machine Learning ecosystem. With its simplicity, vast library support and strong community, Python enables rapid prototyping and smooth model development. It supports complete end to end ML workflows from data preprocessing to deployment making it ideal for both learners and professionals.
# Python Libraries
# Why Python for Machine Learning
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
driver = webdriver.Chrome()
driver.implicitly_wait(5)
driver.get("https://www.geeksforgeeks.org/machine-learning/python-for-machine-learning/")
titles = driver.find_elements(By.NAME, "googlefcPresent")
for t in titles:
    print(t.text)
driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
driver = webdriver.Chrome()
driver.implicitly_wait(5)
driver.get("https://quotes.toscrape.com/")
quotes = driver.find_elements(By.CLASS_NAME, "quote")
for q in quotes:
    print(q.text)
# next_button = driver.find_element(By.XPATH, '//li[@class="next"]/a')
# next_button.click()
driver.quit()
# Out:
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
# by Albert Einstein (about)
# Tags: change deep-thoughts thinking world
# “It is our choices, Harry, that show what we truly are, far more than our abilities.”
# by J.K. Rowling (about)
# Tags: abilities choices
# “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
# by Albert Einstein (about)
# Tags: inspirational life live miracle miracles
# “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”
# by Jane Austen (about)
# Tags: aliteracy books classic humor
# “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”
# by Marilyn Monroe (about)
# Tags: be-yourself inspirational
# “Try not to become a man of success. Rather become a man of value.”
# by Albert Einstein (about)
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://www.w3schools.com/python/default.asp")
content=driver.find_elements(By.CLASS_NAME,"contentcontainer")
for c in content:
    print(c.text)
driver.quit()
# Out:
# Python Tutorial
# Python HOME
# Python Intro
# Python Get Started
# Python Syntax
# Python Output
# Python Comments
# Python Variables
# Python Data Types
# Python Numbers
# Python Casting
# Python Strings
# Python Booleans
# Python Operators
# Python Lists
# Python Tuples
# Python Sets
# Python Dictionaries
# Python If...Else
# Python Match
# Python While Loops
# Python For Loops
# Python Functions
# Python Range
# Python Arrays
# Python Iterators
# Python Modules
# Python Dates
# Python Math
# Python JSON
# Python RegEx
# Python PIP
# Python Try...Except
# Python String Formatting
# Python None
# Python User Input
# Python VirtualEnv
#
# Python Classes
# Python OOP
# Python Classes/Objects
# Python __init__ Method
# Python self Parameter
# Python Class Properties
# Python Class Methods
# Python Inheritance
# Python Polymorphism
# Python Encapsulation
# Python Inner Classes
#
# File Handling
# Python File Handling
# Python Read Files
# Python Write/Create Files
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://www.w3schools.com/python/default.asp")
content=driver.find_elements(By.CLASS_NAME,"topnavcontainer")
for c in content:
    print(c.text)
driver.quit()
# Out:
#      ❯
# HTML CSS JAVASCRIPT SQL PYTHON JAVA PHP HOW TO W3.CSS C C++ C# BOOTSTRAP REACT MYSQL JQUERY EXCEL XML DJANGO NUMPY PANDAS NODEJS DSA TYPESCRIPT ANGULAR ANGULARJS GIT POSTGRESQL MONGODB ASP AI R GO KOTLIN SWIFT SASS VUE GEN AI SCIPY AWS CYBERSECURITY DATA SCIENCE INTRO TO PROGRAMMING INTRO TO HTML & CSS BASH RUST

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://www.w3schools.com/python/default.asp")
content=driver.find_elements(By.CLASS_NAME,"belowtopnavcontainer")
for c in content:
    print(c.text)
driver.quit()
# Out:
# Python Tutorial
# Python HOME
# Python Intro
# Python Get Started
# Python Syntax
# Python Output
# Python Comments
# Python Variables
# Python Data Types
# Python Numbers
# Python Casting
# Python Strings
# Python Booleans
# Python Operators
# Python Lists
# Python Tuples
# Python Sets
# Python Dictionaries
# Python If...Else
# Python Match
# Python While Loops
# Python For Loops
# Python Functions
# Python Range
# Python Arrays
# Python Iterators
# Python Modules
# Python Dates
# Python Math
# Python JSON
# Python RegEx
# Python PIP
# Python Try...Except
# Python String Formatting
# Python None
# Python User Input
# Python VirtualEnv
#
# Python Classes
# Python OOP
# Python Classes/Objects
# Python __init__ Method
# Python self Parameter
# Python Class Properties
# Python Class Methods
# Python Inheritance
# Python Polymorphism
# Python Encapsulation
# Python Inner Classes
#
# File Handling
# Python File Handling
# Python Read Files
# Python Write/Create Files
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://www.w3schools.com/python/default.asp")
h1 = driver.find_element(By.TAG_NAME, "h1")
print(h1.text)
driver.quit()
# Out:
# Python Tutorial

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://www.w3schools.com/python/default.asp")
h1 = driver.find_element(By.ID, "pagetop")
print(h1.text)
driver.quit()
# Out:
# Tutorials
# References
# Exercises
# Certificates
# Search field
#   Sign In
# Get Certified

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://www.w3schools.com/python/default.asp")
anchors = driver.find_elements(By.TAG_NAME, "a")
for a in anchors:
    print(a.text, " -> ", a.get_attribute("href"))
driver.quit()
# Out:
#   ->  https://www.w3schools.com/
# Tutorials  ->  javascript:void(0)
# References  ->  javascript:void(0)
# Exercises  ->  javascript:void(0)
# Certificates  ->  javascript:void(0)
#   ->  javascript:void(0)
#    ->  javascript:void(0)
#   ->  https://profile.w3schools.com/log-in?redirect_url=https%3A%2F%2Fwww.w3schools.com%2Fpython%2Fdefault.asp
# Get Certified  ->  https://campus.w3schools.com/collections/course-catalog
#   ->  https://order.w3schools.com/plans
#   ->  https://www.w3schools.com/academy/index.php
#   ->  https://www.w3schools.com/spaces/index.php
#   ->  https://www.w3schools.com/bootcamp/index.php
#   ->  https://campus.w3schools.com/collections/course-catalog
#   ->  https://order.w3schools.com/plans
#   ->  https://www.w3schools.com/academy/index.php
#   ->  https://spaces.w3schools.com/
#   ->  https://www.w3schools.com/bootcamp/index.php
#   ->  https://pathfinder.w3schools.com/
#   ->  https://www.w3schools.com/spaces/index.php
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
driver = webdriver.Chrome()
driver.get("https://the-internet.herokuapp.com/login")
username = driver.find_element(By.ID, "username")
username.send_keys("nandhini")
password = driver.find_element(By.ID, "password")
password.send_keys("123456")
login_button = driver.find_element(By.CLASS_NAME, "radius")
login_button.click()
driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
driver = webdriver.Chrome()
driver.get("https://www.w3schools.com/python/default.asp")
#Heading
heading = driver.find_element(By.XPATH, "//h1")
print("Heading:", heading.text)
driver.quit()
# Out:
# Heading: Python Tutorial

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://www.w3schools.com/python/default.asp")
paragraph=driver.find_elements(By.XPATH,"//p")
for p in paragraph:
    print(p.text)
driver.quit()
# Out:
# Python is a popular programming language.
# Python can be used on a server to create web applications.
# Tip: Sign in to track your progress.
# With our "Try it Yourself" editor, you can edit Python code and view the result.
# Click on the "Try it Yourself" button to see how it works.
# In our File Handling section you will learn how to open, read, write, and delete files.
# Python File Handling
# In our database section you will learn how to access and work with MySQL and MongoDB databases:
# Python MySQL Tutorial
# Python MongoDB Tutorial
# Many chapters in this tutorial end with an exercise where you can check your level of knowledge.
# What is a correct way to declare a Python variable?
# See all Python Exercises
# REMOVE ADS
# Learn by examples! This tutorial supplements all explanations with clarifying examples.
# See All Python Examples
# Test your Python skills with a quiz.
# Python Quiz
# Sign Up »
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://www.w3schools.com/python/default.asp")
nav_links = driver.find_elements(By.XPATH, "//div[@id='top-nav-bar']//a")
for n in nav_links:
    print(n.text)
# Out:
# Tutorials
# References
# Exercises
# Certificates
#
#
#
# Get Certified

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://www.w3schools.com/python/default.asp")
python_links = driver.find_elements(By.XPATH, "//a[contains(@href, '/python/')]")
print("\nPython Links:")
for link in python_links:
    print("-", link.get_attribute("href"))
driver.quit()
# Out:
# Python Links:
# - https://www.w3schools.com/python/python_ml_getting_started.asp
# - https://www.w3schools.com/python/python_ml_getting_started.asp
# - https://www.w3schools.com/python/numpy/default.asp
# - https://www.w3schools.com/python/numpy/default.asp
# - https://www.w3schools.com/python/pandas/default.asp
# - https://www.w3schools.com/python/pandas/default.asp
# - https://www.w3schools.com/python/scipy/index.php
# - https://www.w3schools.com/python/scipy/index.php
# - https://www.w3schools.com/python/matplotlib_intro.asp
# - https://www.w3schools.com/python/matplotlib_intro.asp
# - https://www.w3schools.com/python/default.asp
# - https://www.w3schools.com/python/default.asp
# - https://www.w3schools.com/python/python_reference.asp
# - https://www.w3schools.com/python/python_ml_getting_started.asp
# - https://www.w3schools.com/python/python_ml_getting_started.asp
# - https://www.w3schools.com/python/numpy/default.asp
# - https://www.w3schools.com/python/numpy/default.asp
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://www.w3schools.com/python/default.asp")
css=driver.find_element(By.CSS_SELECTOR,"h1")
print(css.text)
driver.quit()
# Out:
# Python Tutorial

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://www.w3schools.com/python/default.asp")
css=driver.find_elements(By.CSS_SELECTOR,"p")
for i in css:
    print(i.text)
driver.quit()
# Out:
# Python is a popular programming language.
# Python can be used on a server to create web applications.
# Tip: Sign in to track your progress.
# With our "Try it Yourself" editor, you can edit Python code and view the result.
# Click on the "Try it Yourself" button to see how it works.
# In our File Handling section you will learn how to open, read, write, and delete files.
# Python File Handling
# In our database section you will learn how to access and work with MySQL and MongoDB databases:
# Python MySQL Tutorial
# Python MongoDB Tutorial
# Many chapters in this tutorial end with an exercise where you can check your level of knowledge.
# What is a correct way to declare a Python variable?
# See all Python Exercises
# REMOVE ADS
# Learn by examples! This tutorial supplements all explanations with clarifying examples.
# See All Python Examples
# Test your Python skills with a quiz.
# Python Quiz
# Sign Up »
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
driver=webdriver.Chrome()
driver.get("https://www.w3schools.com/python/default.asp")
images = driver.find_elements(By.CSS_SELECTOR, "img")
for img in images:
    print("Image URL:", img.get_attribute("src"))
driver.quit()
# Out:
# Image URL: https://www.w3schools.com/images/colorpicker2000.png
# Image URL: https://www.w3schools.com/signup/lynxlogo.svg
# Image URL: https://www.w3schools.com/spaces/files/check3.db67d31e.svg
# Image URL: https://www.w3schools.com/spaces/files/check3.db67d31e.svg
# Image URL: https://www.w3schools.com/spaces/files/check3.db67d31e.svg
# Image URL: https://www.w3schools.com/spaces/files/check3.db67d31e.svg
# Image URL: https://www.w3schools.com/spaces/files/check3.db67d31e.svg
# Image URL: https://www.w3schools.com/images/img_2026_fullaccess_300.webp
# Image URL: https://www.w3schools.com/images/colorpicker2000.png
